# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Datasets taken from**
# > https://www.kaggle.com/datasets/muhammadtalhaawan/world-sugar-dataset-2018-2024?select=import_df.csv

# %%
df1 = pd.read_csv('/content/export_df.csv')
df2 = pd.read_csv('/content/import_df.csv')

# %% [markdown]
# # **Task** 🌟

# %% [markdown]
# **Inspect a dataframe with df.head(), df.tail(), df.info(), df.describe().**

# %% [markdown]
# * df.head()

# %%
df1.head()
# Out:
#         Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 0     Brazil  19,600  19,280  32,150  25,950  28,200     32,398  export
# 1   Thailand  10,612   6,695   3,739   7,012  11,000     12,000  export
# 2      India   4,700   5,800   8,406  11,927   6,500      7,000  export
# 3  Australia   3,735   3,600   3,400   3,120   3,270      3,600  export
# 4  Guatemala   2,125   1,858   1,395   1,651   1,657      1,662  export

# %%
df2.head()
# Out:
#              Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 0       Indonesia   5,362   4,758   6,124   5,466   5,800      5,630  import
# 1           China   4,086   3,808   6,379   5,000   4,400      5,000  import
# 2   United_States   2,785   3,778   2,922   3,308   3,126      2,994  import
# 3      Bangladesh   2,429   2,397   2,351   2,807   2,330      2,700  import
# 4  European_Union   2,374   2,235   1,792   1,999   3,000      2,500  import

# %% [markdown]
# * df.tail()

# %%
df1.tail()
# Out:
#            Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 22     Malaysia     123     109     329     316     290        300  export
# 23  Korea_South     306     313     320     280     260        280  export
# 24        China     205     189     132     160     202        250  export
# 25        Other   5,011   4,735   4,492   3,696   4,014      3,706  export
# 26        Total  58,271  53,536  63,925  64,955  66,085     72,104  export

# %%
df2.tail()
# Out:
#           Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 22       Yemen     667     770     941     466     775        875  import
# 23       Chile     449     648     532     654     640        640  import
# 24  Kazakhstan     345     482     478     483     580        625  import
# 25       Other  12,962  12,537  12,422  12,088  12,177     11,653  import
# 26       Total  53,161  53,735  58,704  56,105  57,527     59,012  import

# %% [markdown]
# * df.info()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        27 non-null     object
#  1   2018/19     27 non-null     object
#  2   2019/20     27 non-null     object
#  3   2020/21     27 non-null     object
#  4   2021/22     27 non-null     object
#  5   2022/23     27 non-null     object
#  6   May2023/24  27 non-null     object
#  7   Action      27 non-null     object
# dtypes: object(8)
# memory usage: 1.8+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        27 non-null     object
#  1   2018/19     27 non-null     object
#  2   2019/20     27 non-null     object
#  3   2020/21     27 non-null     object
#  4   2021/22     27 non-null     object
#  5   2022/23     27 non-null     object
#  6   May2023/24  27 non-null     object
#  7   Action      27 non-null     object
# dtypes: object(8)
# memory usage: 1.8+ KB

# %% [markdown]
# * df.describe()

# %%
df1.describe()
# Out:
#           Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# count       27      27      27      27      27      27         27      27
# unique      27      27      25      26      27      27         26       1
# top     Brazil  19,600     300     300  25,950  28,200        300  export
# freq         1       1       2       2       1       1          2      27

# %%
df2.describe()
# Out:
#              Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# count          27      27      27      27      27      27         27      27
# unique         27      27      27      27      27      26         26       1
# top     Indonesia   5,362   4,758   6,124   5,466   1,950      1,000  import
# freq            1       1       1       1       1       2          2      27

# %% [markdown]
# **Creating NaN value**

# %%
np.random.seed(10)
col_name=['2021/22', '2022/23']
mask = np.random.choice([True, False], size=df1[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df1[col_name]=df1[col_name].mask(mask)

df1
# Out:
# [[False False]
#  [ True False]
#  [ True False]
#  [False  True]
#  [False False]
#  [ True False]
#  [False  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True False]
#  [False False]
#  [ True False]
#  [False  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [False  True]
#  [False False]
#  [False False]
#  [False  True]
#  [False  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [False False]]
#            Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 0        Brazil  19,600  19,280  32,150  25,950  28,200     32,398  export
# 1      Thailand  10,612   6,695   3,739     NaN  11,000     12,000  export
# 2         India   4,700   5,800   8,406     NaN   6,500      7,000  export
# 3     Australia   3,735   3,600   3,400   3,120     NaN      3,600  export
# 4     Guatemala   2,125   1,858   1,395   1,651   1,657      1,662  export
# ..          ...     ...     ...     ...     ...     ...        ...     ...
# ...

# %%
np.random.seed(10)
col_name=['2021/22', '2022/23']
mask = np.random.choice([True, False], size=df2[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df2[col_name]=df2[col_name].mask(mask)

df2
# Out:
# [[False False]
#  [ True False]
#  [ True False]
#  [False  True]
#  [False False]
#  [ True False]
#  [False  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True False]
#  [ True False]
#  [False False]
#  [ True False]
#  [False  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [False  True]
#  [False False]
#  [False False]
#  [False  True]
#  [False  True]
#  [ True False]
#  [ True False]
#  [ True False]
#  [False False]]
#               Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 0        Indonesia   5,362   4,758   6,124   5,466   5,800      5,630  import
# 1            China   4,086   3,808   6,379     NaN   4,400      5,000  import
# 2    United_States   2,785   3,778   2,922     NaN   3,126      2,994  import
# 3       Bangladesh   2,429   2,397   2,351   2,807     NaN      2,700  import
# 4   European_Union   2,374   2,235   1,792   1,999   3,000      2,500  import
# ...

# %% [markdown]
# **Show how many missing values in your data, each column.**

# %%
df1.isnull().sum()
# Out:
# Name           0
# 2018/19        0
# 2019/20        0
# 2020/21        0
# 2021/22       15
# 2022/23        6
# May2023/24     0
# Action         0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Name           0
# 2018/19        0
# 2019/20        0
# 2020/21        0
# 2021/22       15
# 2022/23        6
# May2023/24     0
# Action         0
# dtype: int64

# %% [markdown]
# **Manipulate how a dataframe displays in Jupyter by modifying Pandas configuration options such as pd.set_option("display.max_rows", n).**

# %%
pd.set_option("display.max_rows", 10)
df1
# Out:
#            Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 0        Brazil  19,600  19,280  32,150  25,950  28,200     32,398  export
# 1      Thailand  10,612   6,695   3,739     NaN  11,000     12,000  export
# 2         India   4,700   5,800   8,406     NaN   6,500      7,000  export
# 3     Australia   3,735   3,600   3,400   3,120     NaN      3,600  export
# 4     Guatemala   2,125   1,858   1,395   1,651   1,657      1,662  export
# ..          ...     ...     ...     ...     ...     ...        ...     ...
# 22     Malaysia     123     109     329     316     NaN        300  export
# 23  Korea_South     306     313     320     NaN     260        280  export
# 24        China     205     189     132     NaN     202        250  export
# 25        Other   5,011   4,735   4,492     NaN   4,014      3,706  export
# 26        Total  58,271  53,536  63,925  64,955  66,085     72,104  export
#
# [27 rows x 8 columns]

# %%
pd.set_option("display.max_rows", 10)
df2
# Out:
#               Name 2018/19 2019/20 2020/21 2021/22 2022/23 May2023/24  Action
# 0        Indonesia   5,362   4,758   6,124   5,466   5,800      5,630  import
# 1            China   4,086   3,808   6,379     NaN   4,400      5,000  import
# 2    United_States   2,785   3,778   2,922     NaN   3,126      2,994  import
# 3       Bangladesh   2,429   2,397   2,351   2,807     NaN      2,700  import
# 4   European_Union   2,374   2,235   1,792   1,999   3,000      2,500  import
# ..             ...     ...     ...     ...     ...     ...        ...     ...
# 22           Yemen     667     770     941     466     NaN        875  import
# 23           Chile     449     648     532     NaN     640        640  import
# 24      Kazakhstan     345     482     478     NaN     580        625  import
# 25           Other  12,962  12,537  12,422     NaN  12,177     11,653  import
# 26           Total  53,161  53,735  58,704  56,105  57,527     59,012  import
#
# [27 rows x 8 columns]

# %% [markdown]
# **Rename columns of a dataframe using the df.rename() function or by accessing the df.columns attribute.**

# %%
df1.rename(columns = {'Name': 'Country',
                      '2018/19': '2018 - 2019',
                      '2019/20': '2019 - 2020',
                      '2020/21': '2020 - 2021',
                      '2021/22': '2021 - 2022',
                      '2022/23': '2022 - 2023',
                      'May2023/24': 'May 2023 - 2024'}, inplace = True)

df1.columns
# Out:
# Index(['Country', '2018 - 2019', '2019 - 2020', '2020 - 2021', '2021 - 2022',
#        '2022 - 2023', 'May 2023 - 2024', 'Action'],
#       dtype='object')

# %%
df2.rename(columns = {'Name': 'Country',
                      '2018/19': '2018 - 2019',
                      '2019/20': '2019 - 2020',
                      '2020/21': '2020 - 2021',
                      '2021/22': '2021 - 2022',
                      '2022/23': '2022 - 2023',
                      'May2023/24': 'May 2023 - 2024'}, inplace = True)

df2.columns
# Out:
# Index(['Country', '2018 - 2019', '2019 - 2020', '2020 - 2021', '2021 - 2022',
#        '2022 - 2023', 'May 2023 - 2024', 'Action'],
#       dtype='object')

# %% [markdown]
# **Modify the index name and index values of a dataframe using .set_index(), .reset_index() , df.index.name, .index.**

# %% [markdown]
# * .set_index()

# %%
df1.set_index('Country')
# Out:
#             2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022 2022 - 2023  \
# Country
# Brazil           19,600      19,280      32,150      25,950      28,200
# Thailand         10,612       6,695       3,739         NaN      11,000
# India             4,700       5,800       8,406         NaN       6,500
# Australia         3,735       3,600       3,400       3,120         NaN
# Guatemala         2,125       1,858       1,395       1,651       1,657
# ...                 ...         ...         ...         ...         ...
# Malaysia            123         109         329         316         NaN
# Korea_South         306         313         320         NaN         260
# China               205         189         132         NaN         202
# Other             5,011       4,735       4,492         NaN       4,014
# Total            58,271      53,536      63,925      64,955      66,085
#
#             May 2023 - 2024  Action
# Country
# Brazil               32,398  export
# ...

# %%
df2.set_index('Country')
# Out:
#                2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022 2022 - 2023  \
# Country
# Indonesia            5,362       4,758       6,124       5,466       5,800
# China                4,086       3,808       6,379         NaN       4,400
# United_States        2,785       3,778       2,922         NaN       3,126
# Bangladesh           2,429       2,397       2,351       2,807         NaN
# European_Union       2,374       2,235       1,792       1,999       3,000
# ...                    ...         ...         ...         ...         ...
# Yemen                  667         770         941         466         NaN
# Chile                  449         648         532         NaN         640
# Kazakhstan             345         482         478         NaN         580
# Other               12,962      12,537      12,422         NaN      12,177
# Total               53,161      53,735      58,704      56,105      57,527
#
#                May 2023 - 2024  Action
# Country
# ...

# %% [markdown]
# * .reset_index()

# %%
df1.reset_index()
# Out:
#     index      Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# 0       0       Brazil      19,600      19,280      32,150      25,950
# 1       1     Thailand      10,612       6,695       3,739         NaN
# 2       2        India       4,700       5,800       8,406         NaN
# 3       3    Australia       3,735       3,600       3,400       3,120
# 4       4    Guatemala       2,125       1,858       1,395       1,651
# ..    ...          ...         ...         ...         ...         ...
# 22     22     Malaysia         123         109         329         316
# 23     23  Korea_South         306         313         320         NaN
# 24     24        China         205         189         132         NaN
# 25     25        Other       5,011       4,735       4,492         NaN
# 26     26        Total      58,271      53,536      63,925      64,955
#
#    2022 - 2023 May 2023 - 2024  Action
# 0       28,200          32,398  export
# ...

# %%
df2.reset_index()
# Out:
#     index         Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# 0       0       Indonesia       5,362       4,758       6,124       5,466
# 1       1           China       4,086       3,808       6,379         NaN
# 2       2   United_States       2,785       3,778       2,922         NaN
# 3       3      Bangladesh       2,429       2,397       2,351       2,807
# 4       4  European_Union       2,374       2,235       1,792       1,999
# ..    ...             ...         ...         ...         ...         ...
# 22     22           Yemen         667         770         941         466
# 23     23           Chile         449         648         532         NaN
# 24     24      Kazakhstan         345         482         478         NaN
# 25     25           Other      12,962      12,537      12,422         NaN
# 26     26           Total      53,161      53,735      58,704      56,105
#
#    2022 - 2023 May 2023 - 2024  Action
# 0        5,800           5,630  import
# ...

# %% [markdown]
# * df.index.name

# %%
df1.index.name = 'Number'
df1
# Out:
#             Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Brazil      19,600      19,280      32,150      25,950
# 1          Thailand      10,612       6,695       3,739         NaN
# 2             India       4,700       5,800       8,406         NaN
# 3         Australia       3,735       3,600       3,400       3,120
# 4         Guatemala       2,125       1,858       1,395       1,651
# ...             ...         ...         ...         ...         ...
# 22         Malaysia         123         109         329         316
# 23      Korea_South         306         313         320         NaN
# 24            China         205         189         132         NaN
# 25            Other       5,011       4,735       4,492         NaN
# 26            Total      58,271      53,536      63,925      64,955
#
#        2022 - 2023 May 2023 - 2024  Action
# Number
# 0           28,200          32,398  export
# 1           11,000          12,000  export
# ...

# %%
df2.index.name = 'Number'
df2
# Out:
#                Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Indonesia       5,362       4,758       6,124       5,466
# 1                China       4,086       3,808       6,379         NaN
# 2        United_States       2,785       3,778       2,922         NaN
# 3           Bangladesh       2,429       2,397       2,351       2,807
# 4       European_Union       2,374       2,235       1,792       1,999
# ...                ...         ...         ...         ...         ...
# 22               Yemen         667         770         941         466
# 23               Chile         449         648         532         NaN
# 24          Kazakhstan         345         482         478         NaN
# 25               Other      12,962      12,537      12,422         NaN
# 26               Total      53,161      53,735      58,704      56,105
#
#        2022 - 2023 May 2023 - 2024  Action
# Number
# 0            5,800           5,630  import
# ...

# %% [markdown]
# * .index

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=27, step=1, name='Number')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=27, step=1, name='Number')

# %% [markdown]
# **Use df.melt() and df.pivot() to reshape dataframes, specifically to make tidy dataframes.**

# %% [markdown]
# * df.melt()

# %%
df1_melted = df1.melt(id_vars = ['Country'],
         value_vars = ['2018 - 2019', '2019 - 2020'],
         var_name = 'Year',
         value_name = 'Weight (Tons)')

df1_melted
# Out:
#         Country         Year Weight (Tons)
# 0        Brazil  2018 - 2019        19,600
# 1      Thailand  2018 - 2019        10,612
# 2         India  2018 - 2019         4,700
# 3     Australia  2018 - 2019         3,735
# 4     Guatemala  2018 - 2019         2,125
# ..          ...          ...           ...
# 49     Malaysia  2019 - 2020           109
# 50  Korea_South  2019 - 2020           313
# 51        China  2019 - 2020           189
# 52        Other  2019 - 2020         4,735
# 53        Total  2019 - 2020        53,536
#
# [54 rows x 3 columns]

# %%
df2_melted = df2.melt(id_vars = ['Country'],
         value_vars = ['2018 - 2019', '2019 - 2020'],
         var_name = 'Year',
         value_name = 'Weight (Tons)')

df2_melted
# Out:
#            Country         Year Weight (Tons)
# 0        Indonesia  2018 - 2019         5,362
# 1            China  2018 - 2019         4,086
# 2    United_States  2018 - 2019         2,785
# 3       Bangladesh  2018 - 2019         2,429
# 4   European_Union  2018 - 2019         2,374
# ..             ...          ...           ...
# 49           Yemen  2019 - 2020           770
# 50           Chile  2019 - 2020           648
# 51      Kazakhstan  2019 - 2020           482
# 52           Other  2019 - 2020        12,537
# 53           Total  2019 - 2020        53,735
#
# [54 rows x 3 columns]

# %% [markdown]
# * df.pivot()

# %%
df1_melted.pivot(index='Country',
                 columns='Year',
                 values='Weight (Tons)')
# Out:
# Year                 2018 - 2019 2019 - 2020
# Country
# Algeria                      208         334
# Australia                  3,735       3,600
# Brazil                    19,600      19,280
# China                        205         189
# Colombia                     801         778
# ...                          ...         ...
# Saudi_Arabia                 353         429
# South_Africa               1,041       1,451
# Thailand                  10,612       6,695
# Total                     58,271      53,536
# United_Arab_Emirates         209         187
#
# [27 rows x 2 columns]

# %%
df2_melted.pivot(index='Country',
                 columns='Year',
                 values='Weight (Tons)')
# Out:
# Year                 2018 - 2019 2019 - 2020
# Country
# Algeria                    2,328       2,468
# Bangladesh                 2,429       2,397
# Canada                     1,268       1,245
# Chile                        449         648
# China                      4,086       3,808
# ...                          ...         ...
# Total                     53,161      53,735
# United_Arab_Emirates       1,579         751
# United_States              2,785       3,778
# Vietnam                      303       1,312
# Yemen                        667         770
#
# [27 rows x 2 columns]

# %% [markdown]
# **Combine dataframes using df.merge() and pd.concat() and know when to use these different methods.**

# %% [markdown]
# * df.merge()

# %%
df_merged = df1.merge(df2, on = 'Country', how = 'inner')
df_merged
# Out:
#                  Country 2018 - 2019_x 2019 - 2020_x 2020 - 2021_x  \
# 0                  India         4,700         5,800         8,406
# 1   United_Arab_Emirates           209           187           792
# 2         European_Union         2,411         1,459         1,278
# 3                Morocco           497           664           681
# 4           Saudi_Arabia           353           429           370
# ..                   ...           ...           ...           ...
# 9               Malaysia           123           109           329
# 10           Korea_South           306           313           320
# 11                 China           205           189           132
# 12                 Other         5,011         4,735         4,492
# 13                 Total        58,271        53,536        63,925
#
#    2021 - 2022_x 2022 - 2023_x May 2023 - 2024_x Action_x 2018 - 2019_y  \
# 0            NaN         6,500             7,000   export         1,300
# ...

# %% [markdown]
# * pd.concat()

# %%
df_concat = pd.concat([df1, df2],
            axis = 1)
df_concat
# Out:
#             Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Brazil      19,600      19,280      32,150      25,950
# 1          Thailand      10,612       6,695       3,739         NaN
# 2             India       4,700       5,800       8,406         NaN
# 3         Australia       3,735       3,600       3,400       3,120
# 4         Guatemala       2,125       1,858       1,395       1,651
# ...             ...         ...         ...         ...         ...
# 22         Malaysia         123         109         329         316
# 23      Korea_South         306         313         320         NaN
# 24            China         205         189         132         NaN
# 25            Other       5,011       4,735       4,492         NaN
# 26            Total      58,271      53,536      63,925      64,955
#
#        2022 - 2023 May 2023 - 2024  Action         Country 2018 - 2019  \
# Number
# ...

# %% [markdown]
# **Apply functions to a dataframe df.apply() and df.applymap()**

# %% [markdown]
# * df.apply()

# %%
df1_applied = df1.copy()

def custom_function(row):
    Country = row['Country']
    Action = row['Action']

    # Extract columns for summing (2018 - 2019 to 2023 - 2024)
    columns_to_sum = row.index[1:-2]

    # Convert columns to numeric and replace NaN values with 0
    numeric_values = pd.to_numeric(row[columns_to_sum].str.replace(',', ''), errors='coerce').fillna(0)

    total_sum = numeric_values.sum()

    # Format the total_sum with commas
    formatted_total_sum = f"{total_sum:,.0f}"

    result = f"{Country} total numeric values for {Action} from 2018 - 2024 is {formatted_total_sum} tons"

    return result

df1_applied['Total'] = df1_applied.apply(custom_function, axis=1)
df1_applied
# Out:
#             Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Brazil      19,600      19,280      32,150      25,950
# 1          Thailand      10,612       6,695       3,739         NaN
# 2             India       4,700       5,800       8,406         NaN
# 3         Australia       3,735       3,600       3,400       3,120
# 4         Guatemala       2,125       1,858       1,395       1,651
# ...             ...         ...         ...         ...         ...
# 22         Malaysia         123         109         329         316
# 23      Korea_South         306         313         320         NaN
# 24            China         205         189         132         NaN
# 25            Other       5,011       4,735       4,492         NaN
# 26            Total      58,271      53,536      63,925      64,955
#
#        2022 - 2023 May 2023 - 2024  Action  \
# Number
# 0           28,200          32,398  export
# ...

# %%
df2_applied = df2.copy()

def custom_function(row):
    Country = row['Country']
    Action = row['Action']

    # Extract columns for summing (2018 - 2019 to 2023 - 2024)
    columns_to_sum = row.index[1:-2]

    # Convert columns to numeric and replace NaN values with 0
    numeric_values = pd.to_numeric(row[columns_to_sum].str.replace(',', ''), errors='coerce').fillna(0)

    total_sum = numeric_values.sum()

    # Format the total_sum with commas
    formatted_total_sum = f"{total_sum:,.0f}"

    result = f"{Country} total numeric values for {Action} from 2018 - 2024 is {formatted_total_sum} tons"

    return result

df2_applied['Total'] = df2_applied.apply(custom_function, axis=1)
df2_applied
# Out:
#                Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Indonesia       5,362       4,758       6,124       5,466
# 1                China       4,086       3,808       6,379         NaN
# 2        United_States       2,785       3,778       2,922         NaN
# 3           Bangladesh       2,429       2,397       2,351       2,807
# 4       European_Union       2,374       2,235       1,792       1,999
# ...                ...         ...         ...         ...         ...
# 22               Yemen         667         770         941         466
# 23               Chile         449         648         532         NaN
# 24          Kazakhstan         345         482         478         NaN
# 25               Other      12,962      12,537      12,422         NaN
# 26               Total      53,161      53,735      58,704      56,105
#
#        2022 - 2023 May 2023 - 2024  Action  \
# Number
# 0            5,800           5,630  import
# ...

# %% [markdown]
# * df.applymap()

# %%
df1_appliedmap = df1.applymap(lambda x: len(str(x)))
df1_appliedmap
# Out:
#         Country  2018 - 2019  2019 - 2020  2020 - 2021  2021 - 2022  \
# Number
# 0             6            6            6            6            6
# 1             8            6            5            5            3
# 2             5            5            5            5            3
# 3             9            5            5            5            5
# 4             9            5            5            5            5
# ...         ...          ...          ...          ...          ...
# 22            8            3            3            3            3
# 23           11            3            3            3            3
# 24            5            3            3            3            3
# 25            5            5            5            5            3
# 26            5            6            6            6            6
#
#         2022 - 2023  May 2023 - 2024  Action
# Number
# 0                 6                6       6
# ...

# %%
df2_appliedmap = df2.applymap(lambda x: len(str(x)))
df2_appliedmap
# Out:
#         Country  2018 - 2019  2019 - 2020  2020 - 2021  2021 - 2022  \
# Number
# 0             9            5            5            5            5
# 1             5            5            5            5            3
# 2            13            5            5            5            3
# 3            10            5            5            5            5
# 4            14            5            5            5            5
# ...         ...          ...          ...          ...          ...
# 22            5            3            3            3            3
# 23            5            3            3            3            3
# 24           10            3            3            3            3
# 25            5            6            6            6            3
# 26            5            6            6            6            6
#
#         2022 - 2023  May 2023 - 2024  Action
# Number
# 0                 5                5       6
# ...

# %% [markdown]
# **Find the data which satisfy specific condition using df.query()**

# %%
df_queried = df_merged.query("`Country` == 'Indonesia' or `Country` == 'Malaysia'")
df_queried
# Out:
#      Country 2018 - 2019_x 2019 - 2020_x 2020 - 2021_x 2021 - 2022_x  \
# 5  Indonesia             0            11            97           NaN
# 9   Malaysia           123           109           329           316
#
#   2022 - 2023_x May 2023 - 2024_x Action_x 2018 - 2019_y 2019 - 2020_y  \
# 5           440               450   export         5,362         4,758
# 9           NaN               300   export         2,139         1,966
#
#   2020 - 2021_y 2021 - 2022_y 2022 - 2023_y May 2023 - 2024_y Action_y
# 5         6,124         5,466         5,800             5,630   import
# 9         2,142           NaN         2,100             2,340   import

# %% [markdown]
# **Perform grouping and aggregating operations using df.groupby() and df.agg()**

# %% [markdown]
# * df.groupby()

# %%
df_grouped = df_merged.groupby(['Country']).count()
df_grouped
# Out:
#                       2018 - 2019_x  2019 - 2020_x  2020 - 2021_x  \
# Country
# Algeria                           1              1              1
# China                             1              1              1
# Egypt                             1              1              1
# European_Union                    1              1              1
# India                             1              1              1
# ...                             ...            ...            ...
# Nigeria                           1              1              1
# Other                             1              1              1
# Saudi_Arabia                      1              1              1
# Total                             1              1              1
# United_Arab_Emirates              1              1              1
#
#                       2021 - 2022_x  2022 - 2023_x  May 2023 - 2024_x  \
# Country
# Algeria                           1              0                  1
# ...

# %% [markdown]
# * df.agg()

# %%
df1_copy = df1.copy()

year_columns = ['2018 - 2019', '2019 - 2020', '2020 - 2021', '2021 - 2022', '2022 - 2023', 'May 2023 - 2024']
df1_copy[year_columns] = df1_copy[year_columns].replace(',', '', regex=True).astype(float)


df_agg1 = df1_copy[year_columns].agg(['min', 'max'])

# Format the result to include commas
formatted_df_agg1 = df_agg1.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg1
# Out:
#     2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022 2022 - 2023  \
# min           0          11           0         300         202
# max      58,271      53,536      63,925      64,955      66,085
#
#     May 2023 - 2024
# min             250
# max          72,104

# %%
df2_copy = df2.copy()

year_columns = ['2018 - 2019', '2019 - 2020', '2020 - 2021', '2021 - 2022', '2022 - 2023', 'May 2023 - 2024']
df2_copy[year_columns] = df2_copy[year_columns].replace(',', '', regex=True).astype(float)


df_agg2 = df2_copy[year_columns].agg(['min', 'max'])

# Format the result to include commas
formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg2
# Out:
#     2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022 2022 - 2023  \
# min         303         432         478         340         580
# max      53,161      53,735      58,704      56,105      57,527
#
#     May 2023 - 2024
# min             625
# max          59,012

# %% [markdown]
# **Perform aggregating methods on grouped or ungrouped objects such as finding the minimum, maximum and sum of values in a dataframe using df.agg().**

# %% [markdown]
# * Ungrouped Objects

# %%
df_merged_copy = df_merged.copy()

year_columns = ['2018 - 2019_x',
                '2019 - 2020_x',
                '2020 - 2021_x',
                '2021 - 2022_x',
                '2022 - 2023_x',
                'May 2023 - 2024_x',
                '2018 - 2019_y',
                '2019 - 2020_y',
                '2020 - 2021_y',
                '2021 - 2022_y',
                '2022 - 2023_y',
                'May 2023 - 2024_y']

df_merged_copy[year_columns] = df_merged_copy[year_columns].replace(',', '', regex=True).astype(float)

df_agg2 = df_merged_copy[year_columns].agg(['min', 'max', 'sum'])

# Format the result to include commas
formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg2
# Out:
#     2018 - 2019_x 2019 - 2020_x 2020 - 2021_x 2021 - 2022_x 2022 - 2023_x  \
# min             0            11            97           300           202
# max        58,271        53,536        63,925        64,955        66,085
# sum        72,794        68,366        81,786        67,196        80,239
#
#     May 2023 - 2024_x 2018 - 2019_y 2019 - 2020_y 2020 - 2021_y 2021 - 2022_y  \
# min               250           860           751           830           340
# max            72,104        53,161        53,735        58,704        56,105
# sum            88,505        92,462        90,552       100,389        66,985
#
#     2022 - 2023_y May 2023 - 2024_y
# min           830               930
# max        57,527            59,012
# sum        94,707            99,749

# %% [markdown]
# * Grouped Objects

# %%
df_merged_copy = df_merged.copy()

year_columns = ['2018 - 2019_x',
                '2019 - 2020_x',
                '2020 - 2021_x',
                '2021 - 2022_x',
                '2022 - 2023_x',
                'May 2023 - 2024_x',
                '2018 - 2019_y',
                '2019 - 2020_y',
                '2020 - 2021_y',
                '2021 - 2022_y',
                '2022 - 2023_y',
                'May 2023 - 2024_y']

df_merged_copy[year_columns] = df_merged_copy[year_columns].replace(',', '', regex=True).astype(float)

# Group by the relevant columns
grouped = df_merged_copy.groupby('Country')

df_agg2 = grouped[year_columns].agg(['min', 'max', 'sum'])

# Format the result to include commas
formatted_df_agg2 = df_agg2.applymap(lambda x: f"{x:,.0f}")
formatted_df_agg2
# Out:
#                      2018 - 2019_x                 2019 - 2020_x          \
#                                min     max     sum           min     max
# Country
# Algeria                        208     208     208           334     334
# China                          205     205     205           189     189
# Egypt                          200     200     200           300     300
# European_Union               2,411   2,411   2,411         1,459   1,459
# India                        4,700   4,700   4,700         5,800   5,800
# ...                            ...     ...     ...           ...     ...
# Nigeria                        300     300     300           300     300
# Other                        5,011   5,011   5,011         4,735   4,735
# Saudi_Arabia                   353     353     353           429     429
# Total                       58,271  58,271  58,271        53,536  53,536
# United_Arab_Emirates           209     209     209           187     187
#
# ...

# %% [markdown]
# **Remove or fill missing values in a dataframe with df.dropna() and df.fillna() please practice using different method of filling missing value.**

# %% [markdown]
# * df.dropna()

# %%
df1_dropped = df1.dropna()
df1_dropped
# Out:
#              Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0             Brazil      19,600      19,280      32,150      25,950
# 4          Guatemala       2,125       1,858       1,395       1,651
# 12      South_Africa       1,041       1,451       1,007         595
# 19           Nigeria         300         300         300         350
# 20         Mauritius         347         396         369         324
# 26             Total      58,271      53,536      63,925      64,955
#
#        2022 - 2023 May 2023 - 2024  Action
# Number
# 0           28,200          32,398  export
# 4            1,657           1,662  export
# 12             635             650  export
# 19             350             355  export
# 20             335             335  export
# 26          66,085          72,104  export

# %%
df2_dropped = df2.dropna()
df2_dropped
# Out:
#                Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Indonesia       5,362       4,758       6,124       5,466
# 4       European_Union       2,374       2,235       1,792       1,999
# 12             Vietnam         303       1,312       1,325       1,490
# 19                Iran         935       1,111       1,421         973
# 20               Egypt         860         830         830         830
# 26               Total      53,161      53,735      58,704      56,105
#
#        2022 - 2023 May 2023 - 2024  Action
# Number
# 0            5,800           5,630  import
# 4            3,000           2,500  import
# 12           1,520           1,575  import
# 19             989           1,000  import
# 20             830             930  import
# 26          57,527          59,012  import

# %% [markdown]
# * df.fillna()

# %%
df_filled = df_merged.fillna('-')
df_filled
# Out:
#                  Country 2018 - 2019_x 2019 - 2020_x 2020 - 2021_x  \
# 0                  India         4,700         5,800         8,406
# 1   United_Arab_Emirates           209           187           792
# 2         European_Union         2,411         1,459         1,278
# 3                Morocco           497           664           681
# 4           Saudi_Arabia           353           429           370
# ..                   ...           ...           ...           ...
# 9               Malaysia           123           109           329
# 10           Korea_South           306           313           320
# 11                 China           205           189           132
# 12                 Other         5,011         4,735         4,492
# 13                 Total        58,271        53,536        63,925
#
#    2021 - 2022_x 2022 - 2023_x May 2023 - 2024_x Action_x 2018 - 2019_y  \
# 0              -         6,500             7,000   export         1,300
# ...

# %% [markdown]
# **Practice imputing missing values using the SimpleImputer Class in sklearn**

# %%
from sklearn.impute import SimpleImputer

df1_copy = df1.copy()

imputer = SimpleImputer(strategy='mean')

year_columns_to_input = ['2021 - 2022', '2022 - 2023']

df1_copy[year_columns_to_input] = df1_copy[year_columns_to_input].applymap(lambda x: float(str(x).replace(',', '')))
df1_copy[year_columns_to_input] = imputer.fit_transform(df1_copy[year_columns_to_input])

df1_copy[year_columns_to_input] = df1_copy[year_columns_to_input].applymap(lambda x: f"{x:,.0f}")

df1_copy
# Out:
#             Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Brazil      19,600      19,280      32,150      25,950
# 1          Thailand      10,612       6,695       3,739       8,272
# 2             India       4,700       5,800       8,406       8,272
# 3         Australia       3,735       3,600       3,400       3,120
# 4         Guatemala       2,125       1,858       1,395       1,651
# ...             ...         ...         ...         ...         ...
# 22         Malaysia         123         109         329         316
# 23      Korea_South         306         313         320       8,272
# 24            China         205         189         132       8,272
# 25            Other       5,011       4,735       4,492       8,272
# 26            Total      58,271      53,536      63,925      64,955
#
#        2022 - 2023 May 2023 - 2024  Action
# Number
# 0           28,200          32,398  export
# 1           11,000          12,000  export
# ...

# %%
from sklearn.impute import SimpleImputer

df2_copy = df2.copy()

imputer = SimpleImputer(strategy='mean')

year_columns_to_input = ['2021 - 2022', '2022 - 2023']

df2_copy[year_columns_to_input] = df2_copy[year_columns_to_input].applymap(lambda x: float(str(x).replace(',', '')))
df2_copy[year_columns_to_input] = imputer.fit_transform(df2_copy[year_columns_to_input])

df2_copy[year_columns_to_input] = df2_copy[year_columns_to_input].applymap(lambda x: f"{x:,.0f}")

df2_copy
# Out:
#                Country 2018 - 2019 2019 - 2020 2020 - 2021 2021 - 2022  \
# Number
# 0            Indonesia       5,362       4,758       6,124       5,466
# 1                China       4,086       3,808       6,379       6,243
# 2        United_States       2,785       3,778       2,922       6,243
# 3           Bangladesh       2,429       2,397       2,351       2,807
# 4       European_Union       2,374       2,235       1,792       1,999
# ...                ...         ...         ...         ...         ...
# 22               Yemen         667         770         941         466
# 23               Chile         449         648         532       6,243
# 24          Kazakhstan         345         482         478       6,243
# 25               Other      12,962      12,537      12,422       6,243
# 26               Total      53,161      53,735      58,704      56,105
#
#        2022 - 2023 May 2023 - 2024  Action
# Number
# 0            5,800           5,630  import
# ...

# %% [markdown]
# # **Extra Miles** 🌟

# %% [markdown]
# **clean your text data using regex function**

# %% [markdown]
# *   Before cleaning the text data

# %%
df_merged
# Out:
#                  Country 2018 - 2019_x 2019 - 2020_x 2020 - 2021_x  \
# 0                  India         4,700         5,800         8,406
# 1   United_Arab_Emirates           209           187           792
# 2         European_Union         2,411         1,459         1,278
# 3                Morocco           497           664           681
# 4           Saudi_Arabia           353           429           370
# ..                   ...           ...           ...           ...
# 9               Malaysia           123           109           329
# 10           Korea_South           306           313           320
# 11                 China           205           189           132
# 12                 Other         5,011         4,735         4,492
# 13                 Total        58,271        53,536        63,925
#
#    2021 - 2022_x 2022 - 2023_x May 2023 - 2024_x Action_x 2018 - 2019_y  \
# 0            NaN         6,500             7,000   export         1,300
# ...

# %% [markdown]
# * Cleaning

# %%
import re

# %%
def clean_text_with_regex(text):
    if pd.notna(text):  # Skip NaN values
        cleaned_text = re.sub(r'[^\w\s]+', '', text)  # Remove non-alphanumeric characters
        return cleaned_text
    else:
        return text

columns_to_clean = ['2018 - 2019_x',
                    '2019 - 2020_x',
                    '2020 - 2021_x',
                    '2021 - 2022_x',
                    '2022 - 2023_x',
                    'May 2023 - 2024_x',
                    '2018 - 2019_y',
                    '2019 - 2020_y',
                    '2020 - 2021_y',
                    '2021 - 2022_y',
                    '2022 - 2023_y',
                    'May 2023 - 2024_y']

for column in columns_to_clean:
    df_merged[column] = df_merged[column].apply(clean_text_with_regex)

# %% [markdown]
# *  After cleaning the text data

# %%
df_merged
# Out:
#                  Country 2018 - 2019_x 2019 - 2020_x 2020 - 2021_x  \
# 0                  India          4700          5800          8406
# 1   United_Arab_Emirates           209           187           792
# 2         European_Union          2411          1459          1278
# 3                Morocco           497           664           681
# 4           Saudi_Arabia           353           429           370
# ..                   ...           ...           ...           ...
# 9               Malaysia           123           109           329
# 10           Korea_South           306           313           320
# 11                 China           205           189           132
# 12                 Other          5011          4735          4492
# 13                 Total         58271         53536         63925
#
#    2021 - 2022_x 2022 - 2023_x May 2023 - 2024_x Action_x 2018 - 2019_y  \
# 0            NaN          6500              7000   export          1300
# ...

# %% [markdown]
# **clean the text and nested json in**
# > https://raw.githubusercontent.com/nnqomariyah/Fundamentals_of_Data_Science/main/week_3/data/movies_metadata.csv

# %%
import json

# %%
url = 'https://raw.githubusercontent.com/nnqomariyah/Fundamentals_of_Data_Science/main/week_3/data/movies_metadata.csv'
df3 = pd.read_csv(url)
# Out:
# <ipython-input-1822-8ad7edba1c73>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv(url)

# %% [markdown]
# *   Before cleaning the text data

# %%
df3.info()
df3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# *   Cleaning

# %%
def clean_text(text):
    if pd.notna(text): # Skip NaN values
        cleaned_text = re.sub(r'\s+', ' ', text) # Remove extra whitespace and replace with a single space
        return cleaned_text
    else:
        return text

columns_to_clean = ['original_title', 'overview', 'tagline', 'title']

for column in columns_to_clean:
    df3[column] = df3[column].apply(clean_text)

# 'belongs_to_collection' column
def clean_belongs_to_collection(collection):
    if pd.notna(collection):
        match = re.search(r"'name':\s*'([^']+)'", collection) # Extract the 'name' field
        if match:
            return match.group(1)
    return None

df3['belongs_to_collection'] = df3['belongs_to_collection'].apply(clean_belongs_to_collection)

# 'production_companies' column
def clean_production_companies(companies):
    if pd.notna(companies):
        try:
            companies = json.loads(companies.replace("'", "\""))
            company_list = [item['name'] for item in companies]
            return ', '.join(company_list)
        except (json.JSONDecodeError, KeyError):
            return None
    return None

df3['production_companies'] = df3['production_companies'].apply(clean_production_companies)

# 'production_countries' column
def clean_production_countries(countries):
    if pd.notna(countries):
        try:
            countries = json.loads(countries.replace("'", "\""))
            if isinstance(countries, list):
                country_list = [item['name'] for item in countries]
                return ', '.join(country_list)
        except (json.JSONDecodeError, KeyError):
            return None
    return None

df3['production_countries'] = df3['production_countries'].apply(clean_production_countries)

# 'runtime' column
def format_runtime(runtime):
    if pd.notna(runtime):
        return f'{int(runtime)} mins'
    return None

df3['runtime'] = df3['runtime'].apply(format_runtime)

# 'genres' column
df3['genres'] = df3['genres'].apply(lambda x: eval(x) if pd.notna(x) else []) # Convert to a list of dictionaries
df3['genres'] = df3['genres'].apply(lambda x: ', '.join(item['name'] for item in x))

# 'spoken_languages' column
df3['spoken_languages'] = df3['spoken_languages'].apply(lambda x: eval(x) if pd.notna(x) else [])
df3['spoken_languages_names'] = df3['spoken_languages'].apply(lambda x: ', '.join(item['name'] for item in x))
df3 = df3.drop(columns=['spoken_languages']) # Drop original column

# 'budget' column
def clean_budget(budget):
    if pd.notna(budget):
        numeric_budget = re.sub(r'[^\d]+', '', budget) # Remove non-numeric characters
        return numeric_budget
    return None

df3['budget'] = df3['budget'].apply(clean_budget)

# Add commas for numbers
def format_with_commas(number):
    if pd.notna(number):
        return '{:,}'.format(int(number))
    return None

df3['budget'] = df3['budget'].apply(format_with_commas)
df3['revenue'] = df3['revenue'].apply(format_with_commas)

# 'homepage' column
def clean_homepage(url):
    if pd.notna(url):
        if not url.startswith(('http://', 'https://')):
            return None
        return url
    return None

df3['homepage'] = df3['homepage'].apply(clean_homepage)

# 'tagline' column
def clean_tagline(tagline):
    if pd.notna(tagline):
        cleaned_tagline = re.sub(r'[^\w\s]+', ' ', tagline)  # Remove non-alphanumeric characters
        cleaned_tagline = re.sub(r'\s+', ' ', cleaned_tagline).strip() # Remove extra whitespace
        return cleaned_tagline
    return None

df3['tagline'] = df3['tagline'].apply(clean_tagline)

# 'vote_average' column
df3['vote_average'] = df3['vote_average'].apply(lambda x: float(x) if pd.notna(x) else None)

# 'vote_count' column
df3['vote_count'] = df3['vote_count'].apply(lambda x: f'{int(x):,}' if pd.notna(x) else None)

# Dropping NaN values
df3.dropna(inplace=True)

# Drop 'adult', 'video', 'original_language' columns
df3.drop(columns=['adult', 'video', 'original_language'], inplace=True)

# Rearranging columns
columns_order = [
    'id',
    'imdb_id',
    'title',
    'original_title',
    'spoken_languages_names',
    'belongs_to_collection',
    'release_date',
    'genres',
    'tagline',
    'overview',
    'runtime',
    'production_companies',
    'production_countries',
    'budget',
    'revenue',
    'vote_average',
    'vote_count',
    'popularity',
    'homepage',
    'status',
    'poster_path'
]
df3 = df3[columns_order]

# Renaming columns
columns_rename = {
    'id': 'ID',
    'imdb_id': 'IMDB ID',
    'title': 'Title',
    'original_title': 'Original Title',
    'spoken_languages_names': 'Spoken Languages',
    'belongs_to_collection': 'Collection',
    'release_date': 'Release Date',
    'genres': 'Genres',
    'tagline': 'Tagline',
    'overview': 'Overview',
    'runtime': 'Runtime',
    'production_companies': 'Production Companies',
    'production_countries': 'Production Countries',
    'budget': 'Budget',
    'revenue': 'Revenue',
    'vote_average': 'Vote Average',
    'vote_count': 'Vote Count',
    'popularity': 'Popularity',
    'homepage': 'Homepage',
    'status': 'Status',
    'poster_path': 'Poster Path'
}

# Rename the columns in the DataFrame
df3.rename(columns = columns_rename, inplace = True)

# %% [markdown]
# *   After cleaning the text data

# %%
df3.info()
df3.to_csv('cleaned_movies_metadata.csv', index=False)
df3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658 entries, 9 to 45029
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    658 non-null    object
#  1   IMDB ID               658 non-null    object
#  2   Title                 658 non-null    object
#  3   Original Title        658 non-null    object
#  4   Spoken Languages      658 non-null    object
#  5   Collection            658 non-null    object
#  6   Release Date          658 non-null    object
#  7   Genres                658 non-null    object
#  8   Tagline               658 non-null    object
#  9   Overview              658 non-null    object
#  10  Runtime               658 non-null    object
#  11  Production Companies  658 non-null    object
#  12  Production Countries  658 non-null    object
#  13  Budget                658 non-null    object
#  14  Revenue               658 non-null    object
# ...
